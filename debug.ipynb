# %%
import pandas as pd
from datatools import DataSet

# %%
toptier = DataSet("TopTierByCity.csv", "toptier")

# %%
toptier.preprocessData
# Out:
#        RegionID  SizeRank   RegionName RegionType StateName State  \
# 0          6181         0     New York       City        NY    NY
# 1         12447         1  Los Angeles       City        CA    CA
# 2         39051         2      Houston       City        TX    TX
# 3         17426         3      Chicago       City        IL    IL
# 4          6915         4  San Antonio       City        TX    TX
# ...         ...       ...          ...        ...       ...   ...
# 26248      8974     29449   Pecks Mill       City        WV    WV
# 26249     25994     29449        Mosby       City        MO    MO
# 26250     52717     29449       Junior       City        WV    WV
# 26251     53661     29449      Oakdale       City        WI    WI
# 26252     11693     30967  Great Lakes       City        IL    IL
#
#                                   Metro          CountyName  1996-01-31  \
# 0           New York-Newark-Jersey City       Queens County    365036.0
# ...

# %%
toptier.clean()

# %%
toptier.preprocessData
# Out:
#           1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# RegionID
# 6181        365036.0    364050.0    363572.0    362762.0    362574.0
# 12447       356868.0    357098.0    357347.0    357839.0    358244.0
# 39051       199239.0    199337.0    199241.0    199397.0    199564.0
# 17426       258053.0    257762.0    257245.0    257169.0    256526.0
# 6915        165306.0    165202.0    165108.0    165032.0    164886.0
# ...              ...         ...         ...         ...         ...
# 8974             NaN         NaN         NaN         NaN         NaN
# 25994            NaN         NaN         NaN         NaN         NaN
# 52717            NaN         NaN         NaN         NaN         NaN
# 53661            NaN         NaN         NaN         NaN         NaN
# 11693            NaN         NaN         NaN         NaN         NaN
#
#           1996-06-30  1996-07-31  1996-08-31  1996-09-30  1996-10-31  ...  \
# ...

# %%
toptier.indexdf
# Out:
#        regionid     cityname statename
# 0          6181     New York        NY
# 1         12447  Los Angeles        CA
# 2         39051      Houston        TX
# 3         17426      Chicago        IL
# 4          6915  San Antonio        TX
# ...         ...          ...       ...
# 26248      8974   Pecks Mill        WV
# 26249     25994        Mosby        MO
# 26250     52717       Junior        WV
# 26251     53661      Oakdale        WI
# 26252     11693  Great Lakes        IL
#
# [26253 rows x 3 columns]

# %%
toptier.split()

# %%
toptier.splittedData['NY']
# Out:
#           1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# RegionID
# 6181        365036.0    364050.0    363572.0    362762.0    362574.0
# 32172            NaN         NaN         NaN         NaN         NaN
# 17222       114991.0    114773.0    114511.0    114073.0    113636.0
# 13550        91150.0     90821.0     90655.0     90731.0     90897.0
# 34937       305946.0    305544.0    305566.0    305523.0    305826.0
# ...              ...         ...         ...         ...         ...
# 17279        47060.0     47227.0     47442.0     47893.0     48348.0
# 13162        84400.0     84153.0     84089.0     83858.0     84320.0
# 30632            NaN         NaN         NaN         NaN         NaN
# 33471        80740.0     80476.0     80090.0     79502.0     79262.0
# 29920            NaN         NaN         NaN         NaN         NaN
#
#           1996-06-30  1996-07-31  1996-08-31  1996-09-30  1996-10-31  ...  \
# ...

# %%
toptier.multi_process(5)
# Out:
# NY CA TX IL PA are to processed together.
# Working on NY
# Working on CA
# Working on TX
# Working on IL
# Working on PA
# NY is done.
# PA is done.
# CA is done.
# IL is done.
# TX is done.
# AZ NV FL IN NC are to processed together.
# Working on AZ
# Working on NV
# Working on FL
# Working on IN
# Working on NC
# NV is done.
# AZ is done.
# IN is done.
# FL is done.
# NC is done.
# OH KY MI CO WA are to processed together.
# Working on OH
# Working on KY
# Working on MI
# Working on CO
# Working on WA
# CO is done.
# WA is done.
# KY is done.
# MI is done.
# OH is done.
# TN MA DC OR MD are to processed together.
# Working on TN
# Working on MA
# Working on DC
# Working on OR
# DC is done.
# Working on MD
# OR is done.
# MA is done.
# MD is done.
# TN is done.
# WI NE NM OK GA are to processed together.
# Working on WI
# Working on NE
# Working on NM
# Working on OK
# Working on GA
# NM is done.
# NE is done.
# OK is done.
# GA is done.
# WI is done.
# ...

# %%
toptier.statelist
# Out:
# array(['NY', 'CA', 'TX', 'IL', 'PA', 'AZ', 'NV', 'FL', 'IN', 'NC', 'OH',
#        'KY', 'MI', 'CO', 'WA', 'TN', 'MA', 'DC', 'OR', 'MD', 'WI', 'NE',
#        'NM', 'OK', 'GA', 'MO', 'VA', 'MN', 'HI', 'LA', 'KS', 'SC', 'AK',
#        'NJ', 'AL', 'ID', 'IA', 'UT', 'AR', 'RI', 'SD', 'MS', 'CT', 'DE',
#        'MT', 'NH', 'ND', 'WY', 'WV', 'ME', 'VT'], dtype=object)

# %%
toptier.processedData
# Out:
# {'NY':          toptier       date  regionid
#  0       365036.0 1996-01-31      6181
#  1       364050.0 1996-02-29      6181
#  2       363572.0 1996-03-31      6181
#  3       362762.0 1996-04-30      6181
#  4       362574.0 1996-05-31      6181
#  ...          ...        ...       ...
#  280522  123844.0 2020-06-30     29920
#  280523  124881.0 2020-07-31     29920
#  280524  125559.0 2020-08-31     29920
#  280525  126317.0 2020-09-30     29920
#  280526  127305.0 2020-10-31     29920
#
#  [280527 rows x 3 columns],
#  'PA':          toptier       date  regionid
#  0       126141.0 1996-01-31     13271
#  1       125899.0 1996-02-29     13271
#  2       125661.0 1996-03-31     13271
#  3       125240.0 1996-04-30     13271
#  4       124903.0 1996-05-31     13271
#  ...          ...        ...       ...
#  247670  283959.0 2020-06-30     12642
#  247671  286957.0 2020-07-31     12642
#  247672  290037.0 2020-08-31     12642
#  247673  293013.0 2020-09-30     12642
# ...
